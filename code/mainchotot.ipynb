# %%
import requests
import yaml
from bs4 import BeautifulSoup
import json
from concurrent.futures import ThreadPoolExecutor

with open('./config/config.yml', 'r') as f:
    config = yaml.safe_load(f)
    
def getData(urlchotot):
    response = requests.get(url=urlchotot)
    soup = BeautifulSoup(response.text, 'html.parser')
    all_results = soup.find_all('div', attrs={'tabindex':"0"})
    for result in all_results:
        data = {}
        data["name"] = result.find('h3',class_="adonovt").text
        data["year"] = result.find('span', class_='c1u6gyxh').text
        data["price"] = result.find('span', class_='bfe6oav').text
        newRequest = requests.get("https://xe.chotot.com"+result.find('a',attrs={'itemprop':'item'}).get('href'))
        newSoup = BeautifulSoup(newRequest.text, 'html.parser')
        data["description"] = newSoup.find('p', attrs={'itemprop':'description'}).text
        data["urlcar"] = "https://xe.chotot.com"+result.find('a',attrs={'itemprop':'item'}).get('href')
        print(json.dumps(data, ensure_ascii=False, indent=2))

def main():
    urlchotot = config['url']['urlchotot']
    listUrl = [urlchotot.format(i) for i in range(1, 1000)]

    with ThreadPoolExecutor(max_workers=10) as executor:
        executor.map(getData, listUrl)

if __name__ == '__main__':
    main()
# Out:
# {
#   "name": "Kia Morning 2015 màu trắng số sàn",
#   "year": "2015",
#   "price": "160.000.000 đ",
#   "description": "bán xe kia morning 2015 màu trắng, số sàn, xe gia đình sử dụng, không đâm va ngập nước. máy móc chất, khoẻ, chạy êm, điều hoà mát",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-ha-dong-ha-noi/117890706.htm"
# }
# {
#   "name": "Mazda 6 2003 2.0 đẹp, zin nguyên bản",
#   "year": "2003",
#   "price": "125.000.000 đ",
#   "description": "Mazda6 bản đủ, zin nguyên bản, xe biển tp, gốc tp, bảo dưỡng kỹ, hoạt động tốt, phân khúc D 2 túi khí, máy 2.0 êm zin, mạnh mẽ, bền bì, ít hao nhiên liệu tầm 8/100kn. Khung gầm chắc chắn, đinh bấm, chỉ khung nhà sản xuất còn zin nguyên, chạy đầm chắc, 4 thắng đĩa, hệ thống ABS chống trơn trượt, bó thắng rất an toàn,  sơn mỏng sáng bóng( sơn zin hơn 50%), nội thất da nỉ zin, trần nỉ zin sáng mới, sàn nỉ zin sạch đẹp ghế bao da, hệ thống chỉnh điện  hoàn hảo zin, hệ thống âm thanh 6 đĩa theo xe nghe rất hay, đã trang bị màn hình androi lớn tích hợp camera  lùi cảm biến lùi, đã dán fim cách nhiệt xịn toàn xe, đã dán fim cách âm, chỉa khóa remot lbock cửa zin theo xe hoạt động tốt, kiểm định còn dài, ký mua bán gút hồ sơ nhanh gọn. Mời ae có nhu cầu đưa kỷ thuật đến xem, teets xem độ chất cúa xe. Thank chợ tốt.",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-huyen-cu-chi-tp-ho-chi-minh/118005009.htm"
# }
# {
#   "name": "Kia Carnival 2008 xe 7 chỗ siêu rộng",
#   "year": "2008",
#   "price": "148.000.000 đ",
#   "description": "Nhà em bán chiếc xe gắn bó lâu nay.\nKia Carnival 2008 mệnh danh phi thuyền mặt đất, xe 7 chỗ số tự động siêu to, siêu rộng, đi gia đình khỏi bàn. \nXe đủ hết trang thiết bị cao cấp, đa dụng: cửa trượt, ghế điện, 3 vùng điều hòa, camera quanh xe... số tự động Vợ Chồng đi đều OK hết, giá bán 148 triệu. \nAi cần alo sớm nhé, vì xe rất đẹp & hiếm. Xem tại Hàm Nghi, Mỹ Đình nhé. Cảm ơn ạ!",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-hai-ba-trung-ha-noi/118136387.htm"
# }
# {
#   "name": "Toyota Hiace 1996 - mobile home",
#   "year": "1996",
#   "price": "52.000.000 đ",
#   "description": "E cần bán chiếc cá mập đời 96, xe hết đăng kiểm về e đã làm lại mobile home, ở trên nóc làm sàn gỗ, trong xe giường đơn giản xếp lại thành ghế, tủ, bàn xếp. Xe máy móc nổ êm ái, chạy bốc, ghế theo xe vẫn còn, xe này nhà a nào gần trong rừng hay cạnh hồ ngồi chill chill thì hết bài. Ae có nhu cầu liên hệ e, e có nhận giao lưu xe khác, ưu tiên suzuki 7 chỗ kaka\nCảm ơn ae đã xem tin",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-thanh-pho-da-lat-lam-dong/118448712.htm"
# }
# {
#   "name": "Mitsubishi Jolie 2005 SS - 135000 km",
#   "year": "2005",
#   "price": "105.000.000 đ",
#   "description": "Xe nhà bán chiếc Mitsubitshi Jolie SS màu vàng, sản xuất năm 2005, xe còn rất đẹp, máy nổ êm ru bao đi xa từ 100 - 500km, xe 2 dàn lạnh còn đầy đù, đăng kiểm còn rất dài đến cuối tháng 04/2025. Xe chính chủ ký giấy mua bán hoặc uỷ quyền đều được. Quý khách có nhu cầu sử dụng vui lòng liên hệ trực tiếp theo SĐT đăng tin, không tiếp cò lái, mai mối, tin nhắn lu bu vì tôi bận đi làm.",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-thanh-pho-soc-trang-soc-trang/117450489.htm"
# }
# {
#   "name": "DEAWOO CIELO",
#   "year": "1996",
#   "price": "28.000.000 đ",
#   "description": "Xe đang sử dụng các chức năng còn rất tốt , xe đẹp , nội thất sang chảnh thơm tho, đi xa OK không hao xăng . Đăng kiểm còn dài \nGiá bán : 28.000.000₫\nXem xe tại CỦ CHI TP HCM đt zalo",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-huyen-cu-chi-tp-ho-chi-minh/117546257.htm"
# }
# {
#   "name": "Toyota Zace 2003 GL - dòng cao cấp",
#   "year": "2003",
#   "price": "138.000.000 đ",
#   "description": "- 🚗 Toyota Zace GL 2003.\n-  xe gia đình cần bán còn rất zin và mới đẹp long lanh chính chủ mới xét lưu hành",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-8-tp-ho-chi-minh/118152245.htm"
# }
# {
#   "name": "Bán xe Innova G 2008",
#   "year": "2008",
#   "price": "198.000.000 đ",
#   "description": "Bán xe Toyota Innova G xịn, năm sản xuất 2008. \nXe tư nhân sử dụng, không dịch vụ\nXe trang bị : túi khí an toàn, abs chống bó cứng phanh, lazang đúc, gương kính điện.\nMáy gầm chất, xe rộng rãi, điều hoà mát, nội ngoai thất đều còn rất đẹp\nbác nào mua xe đi liên hệ trực tiếp nhà e ạ",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-ha-dong-ha-noi/116928209.htm"
# }
# {
#   "name": "xe nhà cần bán một chủ mua mới từ đầu",
#   "year": "2013",
#   "price": "190.000.000 đ",
#   "description": "Chevrolet Lacetti 2013 số sàn, 33000km\n- Xe đẹp, máy êm, chạy cực bốc\n- Xe nguyên bản, không đâm đụng, ngập nước\n- Giá: 190",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-thanh-pho-thu-dau-mot-binh-duong/116177381.htm#px=SR-stickyad-[PO-1][PL-top]"
# }
# {
#   "name": "Toyota Zace 2005 GL",
#   "year": "2005",
#   "price": "155.000.000 đ",
#   "description": "Xe rất đẹp nội thất nỉ zin toàn bộ\nGL 2005\nXe nghiêm chỉnh đi xa tốt tiết kiệm xăng\nGầm bệ và máy số rất êm\n4 vỏ michelin và loa xịn\nMàn hình camera remot lock cửa đầy đủ\nĐã kiểm tra bảo dưỡng\nAnh chị mua về chỉ đổ xăng là chạy\nThiện chí lh và xem xe \nCảm ơn",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-binh-tan-tp-ho-chi-minh/118457692.htm"
# }
# {
#   "name": "Bán Innova 2007 G xịn chính chủ",
#   "year": "2007",
#   "price": "145.000.000 đ",
#   "description": "Cần bán Innova G xịn 2007 chính chủ giá 145 triệu, máy số êm gầm bệ chắc ko mục mọt máy lạnh sâu, sơn xi sáng đẹp, kính bấm chỉnh điện, gương điện, vỏ lốp còn mới mâm đúc đẹp, màn hình 9 inch cam lùi cam hành trình đầy đủ, xe về sẵn đi đổ xăng là chạy bao chạy xa thoải mái, anh chị em có nhu cầu vui lòng add zalo hoặc xem xe trực tiếp tại nhà 1491 Lê Văn Lương Xã Nhơn Đức Huyện Nhà Bè Tphcm",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-huyen-nha-be-tp-ho-chi-minh/118402796.htm"
# }
# {
#   "name": "Ford Focus 1.8 AT 8 vạn xuất sắc zin 100%",
#   "year": "2010",
#   "price": "178.000.000 đ",
#   "description": "Xe vừa mới đăng kiểm xong hết 2025. Chính chủ sử dụng muốn bán lại chiếc Ford Focus đky 2010 1 chủ từ đầu chính chủ biển 30V 4 số từ mới rất lịch sự sang trọng. Nội thất trần nỉ ghế da taply da vẫn zin và đẹp như mới. Xe màu vàng cát nguyên \nbản options đầy đủ lazang đúc,độ rất nhiều đồ chơi đắt tiền như đèn ống bi xenon đèn mí chớp, điều hòa 2 chiều \nmát lạnh, màn hình DVD android, âm thanh surround, camera, cảm biến lùi,gương kính \nchỉnh điện, rất nhiều đồ chơi khác. Xe máy móc nguyên bản 4 lốp mới thay đi nhẹ nhàng êm ái tiết kiệm xăng.Giấy tờ \nđầy đủ sang tên đổi chủ đơn giản. Ai có nhu cầu liên hệ trực tiếp đến nhà xem xe",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-long-bien-ha-noi/117171290.htm"
# }
# {
#   "name": "nubiza 2004",
#   "year": "2004",
#   "price": "35.000.000 đ",
#   "description": "xe dep nôi thât con moi máy so bao chay bac nam , máy lanh tôt vê chi dô xâng là chayko sua chüa j thêm.tiên não cua dó .ko so sánh vói xe nát phai sua ch§a tu bô lai giá trên chi lui lôc ace cân nhãc truõc khi goi tránh mât thoi gian 2 bên\nkhông chín 2 bôn 49 . 49 bôn chín",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-huyen-lam-ha-lam-dong/118448679.htm"
# }
# {
#   "name": "2017 - 111111 km changan 2017 đã qua sử dụng",
#   "year": "2017",
#   "price": "12.345.678 đ",
#   "description": "Hết việc cần bán ae nào cần liên hệ e ạ",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-thanh-pho-di-an-binh-duong/118415929.htm"
# }
# {
#   "name": "MG5 MT - 2024 - chỉ từ 80tr nhận xe về ngay",
#   "year": "2023",
#   "price": "80.000.000 đ",
#   "description": "⚜️ NEW MG5 MT 1.5L ⚜️\n- Xe mới 100% \n- Bảo hành 5 năm không giới hạn Km.\n- Bảo hành 5 năm cứu hộ 24/7.\n- Hỗ trợ đăng ký, đăng kiểm, giao xe tận nhà.\n- Xe có sẵn, giao ngay, đủ màu ( Trắng - Bạc - Đen - Đỏ ) \n- Xe đẹp, sang trọng, tiết kiệm nhiên liệu.\n- Xe phù hợp cho nhu cầu dịch vụ và cả nhu cầu gia đình.\n- Xe được trang bị đầy đủ, chỉ việc đổ xăng là chạy\n\n—————***—————\n🪩25 Võ Văn Kiệt, p16, q8, tpHCM",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-8-tp-ho-chi-minh/116587066.htm#px=SR-stickyad-[PO-2][PL-top]"
# }
# {
#   "name": "MG5 MT - 2024 - chỉ từ 80tr nhận xe về ngay",
#   "year": "2023",
#   "price": "80.000.000 đ",
#   "description": "⚜️ NEW MG5 MT 1.5L ⚜️\n- Xe mới 100% \n- Bảo hành 5 năm không giới hạn Km.\n- Bảo hành 5 năm cứu hộ 24/7.\n- Hỗ trợ đăng ký, đăng kiểm, giao xe tận nhà.\n- Xe có sẵn, giao ngay, đủ màu ( Trắng - Bạc - Đen - Đỏ ) \n- Xe đẹp, sang trọng, tiết kiệm nhiên liệu.\n- Xe phù hợp cho nhu cầu dịch vụ và cả nhu cầu gia đình.\n- Xe được trang bị đầy đủ, chỉ việc đổ xăng là chạy\n\n—————***—————\n🪩25 Võ Văn Kiệt, p16, q8, tpHCM",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-8-tp-ho-chi-minh/116587066.htm#px=SR-stickyad-[PO-1][PL-top]"
# }
# {
#   "name": "Chevrolet Spark 2016 1.0 LS - 6400000 km",
#   "year": "2016",
#   "price": "175.000.000 đ",
#   "description": "- Xe Chevrolet Spark 1.0 LS 2016, màu xanh dương, xe đẹp, giá tốt.\n- Xe đã được kiểm định chất lượng, đảm bảo an toàn khi vận hành.\n- Xe chạy êm, tiết kiệm nhiên liệu.\n- Xe còn mới, không đâm đụng, không ngập nước.\n- Hỗ trợ trả góp với lãi suất ưu đãi.\n- Liên hệ ngay để được tư vấn và lái thử xe!",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-12-tp-ho-chi-minh/117957143.htm"
# }
# {
#   "name": "mình cần bán xe ford escape đời 2002 giá rẻ",
#   "year": "2002",
#   "price": "85.000.000 đ",
#   "description": "Gia đình không dùng nữa bán lại cho ai cần xe còn khá đẹp so với tầm tiền a chị mua về đổ xăng chở con đi học thoải mái đỡ mưa gió mùa này hjhj",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-huyen-tan-phu-dong-nai/118461509.htm"
# }
# {
#   "name": "Lacetti.Dòng xe Max máy 1.8 Nhập khẩu",
#   "year": "2005",
#   "price": "89.000.000 đ",
#   "description": "Cần bán gấp xe Lacetti.Max 1.8 dòng cao cấp nhập khẩu nguyên chiếc nên chạy rất êm và đầm,thắng ABS 4 đĩa.Máy lạnh điện tử nên rất lạnh. Chìa remot zin. Xe màu vàng cát đời 2005,gia đình rất ít sử dụng nên còn rất mới,bộ ghế nỉ zin theo xe . Đã lên dàn âm thanh jbl và màn hình android 9inch wifi loa súp cực hay camera trước,sau rất rõ luôn 4 vỏ mới. Đăng kiểm đến 2025.Đến xem xe và chạy thử sẽ rõ hơn chứ đừng so sánh với những xe bị lỗi nhé. Tiền nào của đó thôi. Chính chủ",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-go-vap-tp-ho-chi-minh/114755105.htm"
# }
# {
#   "name": "Daewoo Matiz 2004 II ME - 1234 km",
#   "year": "2004",
#   "price": "48.000.000 đ",
#   "description": "Matiz SE \n2004 \nchính chủ kí giấy được . máy êm , dàn lạnh còn đu, đi xa vô tư. \n\ncam lùi,body hông,cặp mâm lốp maxis kiểu, đề nổ startstop . \nxe mới đăng kiểm 3/2025 kiểm 1 năm nhé .",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-binh-tan-tp-ho-chi-minh/118405805.htm"
# }
# {
#   "name": "xe matit 5 chổ ngồi số tự động cực mới run100%",
#   "year": "2009",
#   "price": "148.000.000 đ",
#   "description": "Gia đình em cần tiền bán gấp chiếc xe 5 chổ ngồi số tự động xe cực mới. Gầm máy 7 màu chạy êm lắm. Đứng gần bên không nghe tiếng máy nổ êm lắm anh chị. Xe chạy cực kỳ tiết kiệm xăng 5lit/100km em chính chủ ký giấy mua bán bao rút hồ sơ gốc cho khách ơ xa. Em bán có thương lượng giá lộc lá cho anh chị nào đến xem xe mua bán mau lẹ vui vẻ nhiệt tình. Cám ơn anh chị đã xem tin",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-thanh-pho-thuan-an-binh-duong/117250846.htm"
# }
# {
#   "name": "Cần lên xe mới nên mới bán xe tâm huyết caffe",
#   "year": "1983",
#   "price": "50.000.000 đ",
#   "description": "Cần lên xe mới nên mới bán xe tâm huyết cafe máy bao chất chạy Sài Gòn Hà Nội vô tư 100/6lit mới kiểm xong",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-thanh-pho-bien-hoa-dong-nai/116806954.htm"
# }
# {
#   "name": "Chevrolet Captiva Tự Động 2009 Rất Đẹp",
#   "year": "2009",
#   "price": "195.000.000 đ",
#   "description": "- Cần bán gấp Chevrolet Captiva sx 2009 mẫu mới số tự động gia đình ít sử dụng. máy móc nguyên bản, xe đẹp.\n- Xe trang bị đầy đủ tiện nghi: điều hòa, âm thanh, gương kính chỉnh điện, khóa cửa trung tâm, camera lùi, cảm biến lùi...\n- Xe chạy rất êm, tiết kiệm nhiên liệu, phù hợp cho gia đình.xem xe mê ngay. \n- Cam kết xe không lỗi không đâm đụng ngập nước. \n- Giá bán nhanh,: 195tr. Bớt chút đỉnh lộc cho người mua nhanh. \nMIỄN CÒ LÁI QUẢNG CÁO. \nXem xe tại Tân Bình. \nXin cảm ơn.",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-tan-binh-tp-ho-chi-minh/118088585.htm"
# }
# {
#   "name": "Daewoo Lacetti_ 5 chổ sedan đăng kiểm dài",
#   "year": "2005",
#   "price": "69.000.000 đ",
#   "description": "Xe mây móc êm ngon miển bàn\nSố ngọt chạy cao tốc vô tư\nMáy lạnh mạnh\nMàn hình android cảm ứng camera đầy đủ\nÂm thanh điện đóm đèn còi ok hết\nLạc chủ bao tranh chấp trọn đời. Có tranh chấp đền đủ tiền..\nMua alo không sms\nSố tk: 888.888.888 (ngân hàng OCB)",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-binh-tan-tp-ho-chi-minh/118130141.htm"
# }
# {
#   "name": "CẦN MUA XÁC Ô TÔ VÀ XE TẢI TAI NẠN GIÁ CAO",
#   "year": "2017",
#   "price": "120.000.000 đ",
#   "description": "Mình cần thu mua xác ô tô, xe tải, xe khách cũ, bị tai nạn, ngập nước, dính nợ xấu... Các dòng xe Isuzu, Huyndai, Toyota, Mazda, Hino,...\n📌 Dịch vụ đặc biệt:\n✅ Thu mua trên toàn quốc: HCM, Bình Dương, Đà Nẵng, Hà Nội,…\n✅ Giá thu mua cam kết giá tốt, cao hơn thị trường\n✅ Trực tiếp đến tận nơi để xem và báo giá cho khách hàng\n✅ Báo giá ngay khi khách hàng thông tin tình trạng xe\n✅ Nhân viên nhiệt tình, lịch sự\n✅ Không cần tốn nhiều thủ tục và giấy tờ\n✅ Thanh toán bằng tiền mặt một lần nhanh gọn cho khách hàng\n✅ Công ty tự vận chuyển xe, khách hàng không cần lo\n✅ Mua tận nơi 24/7 \nLIÊN HỆ ZALO MÌNH NGAY SĐT BÊN DƯỚI: \n\n#thumuaxe #xetainan #xengapnuoc #xecu #muaxe #cuongthumua #21033454_02",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-thanh-pho-thu-dau-mot-binh-duong/113671018.htm#px=SR-stickyad-[PO-3][PL-top]"
# }
# {
#   "name": "Chevrolet Cruze 2010 LTZ 1.8 . AT số tự động .",
#   "year": "2010",
#   "price": "115.000.000 đ",
#   "description": "🚙 Chevrolet cruze sx2010.. ..số tự động..\n💰 Đưa em.. 115tr.. nhận xe về luôn..\n\n♻️ Xe máy số ngon - đồng sơn sạch đẹp - đã lên màng hình android - nội thất rin sạch sẽ - 4 vỏ dầy cui - bao ko đâm đụng hay ngập nước gi nghe ...\n\n👉 Góp thoải mái Ko cần thủ tục lu bu \n👉 Hổ trợ ace góp trực tiếp với em ko lo nợ xấu ..\n👉 Cho nợ trả chậm ko lấy lãi theo thoa thuận .\n\n🌎 Xem xe gân chân cầu cần thơ \"tx binh minh\"\n💰Giá bán 215tr ..\"báo ký rút hồ sơ xem xe thương lượng\"",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-thi-xa-binh-minh-vinh-long/118399174.htm#px=SR-stickyad-[PO-2][PL-top]"
# }
# {
#   "name": "Grand i10 sedan_bản đủ 1.25 4 máy_1 đời chủ",
#   "year": "2015",
#   "price": "189.000.000 đ",
#   "description": "Xe zin không đâm va\nSản xuất cuối 2015 tư nhân 1 đời chủ đến nay.\nBản đủ 1.25 _4 máy_ vô lăng tích hợp nhiều tiện ích\nĐề startop - 2 chìa remot từ xa đầy đủ\nMâm đúc ghế da thắng đĩa\nKính gương chỉnh điện - gập điện- xi nhan trên gương..\nChống chói tự động. Camera lùi phía sau đầy đủ\nMáy cực kì êm. Nổ không rung. Không nghe 1 tiếng gì luôn... máy lạnh mạnh. Mát teo.\nÂm thanh điện đóm nhạc đầy đủ. Ko lổi thứ gì\nChính chủ mua bao kí uỷ quyền 20 năm kí mua bán gì Ok hết 1 nốt nhạc..\nCall trực tiếp. Ko sms\nSố TK : 888.888.888 (ngân hàng OCB)",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-binh-tan-tp-ho-chi-minh/118106697.htm"
# }
# {
#   "name": "Daewoo Matiz 2006",
#   "year": "2003",
#   "price": "42.000.000 đ",
#   "description": "- 🚗 Daewoo Matiz 2006 bạc, 4 chỗ.\n- ⚙️ Odo: 100.000 km.\n- ⛽️ Sử dụng nhiên liệu Xăng.\n- 💺 Số chỗ ngồi: 4.\n- 💰 Giá bán: 42 triệu (có thương lượng).\n- xe nhà dùng được hơn 1 năm, xe đã sửa hết 18tr mua về chỉ có chạy. Đang kiểm dài. Xem xe text anh em biết. Trước mua 48tr + tiền sửa giờ lỗ quá hớp. Giá trên bớt xăng cộ còn ép giá em không tiếp ạ. Xem xe Thủ Đức",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-thanh-pho-thu-duc-tp-ho-chi-minh/118464282.htm"
# }
# {
#   "name": "Ford Escape 2004 2.3L XLS",
#   "year": "2004",
#   "price": "105.000.000 đ",
#   "description": "Cần bán xe escap số sàn 2.3 chính chủ , xe còn đẹp , đời 203 , dòng xe này số sàn ko hao xăng ai mua lh e nha",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-cai-rang-can-tho/118357561.htm"
# }
# {
#   "name": "Chính chủ cần bán mec C180K",
#   "year": "2004",
#   "price": "120.000.000 đ",
#   "description": "Chính chủ cần bán Mec C180K. Đời 2004, Bảo dưỡng đầy đủ. Mua về chạy không cần bảo dưỡng gì thêm",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-thanh-pho-thu-duc-tp-ho-chi-minh/118459359.htm"
# }
# {
#   "name": "Kia Morning 2018 Si 1.25 MT",
#   "year": "2018",
#   "price": "200.000.000 đ",
#   "description": "Chào bán xe kia morning 2018 số sàn chạy hơn 6 vạn.Xe đẹp xuất sắc không ngày dịch vụ.Tên tư nhân chính chủ đứng bán. Biển Hà Nội a e có khách cầm bán .hỗ trợ Bank",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-hoang-mai-ha-noi/118243294.htm"
# }
# {
#   "name": "THU - MUA GIÁ CAO TẤT CẢ CÁC DÒNG XE OTO",
#   "year": "2023",
#   "price": "50.000.000 đ",
#   "description": "Siêu thị Ô tô Hà Nội thu mua tất cả các dòng xe của các nhãn hiệu xe: Ford, Kia, Mazda, Mitsubishi, Honda, Mitsubishi, Honda, Hyundai, Toyota, Chevrolet, Nissan, Mecerder, BMW, AUDI...\nTầm giá từ 300 triệu trở lên.\n\nCam kết:\n👉 Giá nào cũng mua, giá thu cao nhất.\n 👉 Bảo mật thông tin khách hàng 100%.\n 👉 Thanh toán 100% trong ngày.\n 👉 Hoa hồng cao cho người giới thiệu.\n 👉 Xem xe tận nơi, thu xe 24/7.\n 👉 Hỗ trợ mọi thủ tục, giấy tờ công chứng sang tên.\nCả nhà có xe ới em nhé ạ 😘😘\n___________________________________________\n𝐒𝐢ê𝐮 𝐓𝐡ị Ô 𝐓ô 𝐇à 𝐍ộ𝐢 - Thương hiệu xe lướt số 1 Việt Nam.\n🏣 389 Quốc Lộ 13, Hiệp Bình Phước, Thủ Đức, Hồ Chí Minh.\nCode: #22915352_01",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-thanh-pho-thu-duc-tp-ho-chi-minh/117922237.htm#px=SR-stickyad-[PO-4][PL-top]"
# }
# {
#   "name": "xe nhà cần bán một chủ mua mới từ đầu",
#   "year": "2013",
#   "price": "190.000.000 đ",
#   "description": "Chevrolet Lacetti 2013 số sàn, 33000km\n- Xe đẹp, máy êm, chạy cực bốc\n- Xe nguyên bản, không đâm đụng, ngập nước\n- Giá: 190",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-thanh-pho-thu-dau-mot-binh-duong/116177381.htm#px=SR-stickyad-[PO-3][PL-top]"
# }
# {
#   "name": "Isuzu Trooper 2001 Tôi không rõ - 200 km",
#   "year": "2001",
#   "price": "88.000.000 đ",
#   "description": "Isuzu Trooper 2001 Đỏ 5 chỗ\n\n- Số chỗ ngồi: 5\n- Màu xe: Đỏ\n- Năm sản xuất: 2001\n- Xe đã đi: 100000 km\n\nLợi ích khi mua xe\n💎 Pháp lý, lịch sử xe rõ ràng; 100% không đâm đụng, không ngập nước, không tua đồng hồ\n💎 Xe được kiểm định có cam kết chất lượng bằng văn bản\n💎 Cam kết hoàn tiền trong 7 ngày\n💎 Bao kiểm tra tại các hãng trên toàn quốc\n💎 Hỗ trợ cho vay tới 70% giá trị xe, duyệt hồ sơ trên ứng dụng nhanh chỉ 5 phút\n💎 Hỗ trợ làm thủ tục sang tên, giao xe tận nơi\n\n📞  là nơi mua bán ô tô đã qua sử dụng uy tín hàng đầu Việt Nam",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-huyen-binh-chanh-tp-ho-chi-minh/118268683.htm"
# }
# {
#   "name": "Xe morning 2014 máy 1.25 như mới ạ",
#   "year": "2014",
#   "price": "138.000.000 đ",
#   "description": "Gia đình em bán chiếc Morning 2014 gắn bó đã lâu, xe bản 1.25 bốn máy cực khỏe, bền, tiết kiệm xăng, xe mới đăng kiểm. Bảo dưỡng rất cẩn thận nên còn mới lắm, trần nỉ em bọc nilong, xe ko vết sước, giá bán 138 triệu. \nAi cần alo xem xe o Cầu giấy, miễn thợ thuyền trung gian vì e rất bận.\nCam kết xem xe ưng ngay ạ. Cảm ơn (xe full đồ như bản đủ, màn hình, lazzang đúc, khóa khiển... 4 lốp mới ạ)",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-hai-ba-trung-ha-noi/118312082.htm"
# }
# {
#   "name": "Kia Morning 2011 Van 1.0 AT - 100000 km",
#   "year": "2011",
#   "price": "140.000.000 đ",
#   "description": "- Xe Kia Morning Van 1.0 AT sản xuất năm 2011, màu trắng, số tự động, máy móc nguyên bản.\n- Xe đã đi 100.000 km, nội thất sạch sẽ, máy móc nguyên bản.\n- Xe được trang bị đầy đủ các tiện nghi như: điều hòa, âm thanh, gương kính, màn hình\n- Xe được bảo dưỡng định kỳ đầy đủ, lịch sử bảo dưỡng rõ ràng.\n- Xe gia đình không kinh doanh vận tải, hàng ngày chỉ dùng để đưa con đi học. Cam kết xe không đâm đụng, không ngập nước, máy móc nguyên bản.\n- Xe vừa đăng Kiểm đầu tháng 8-2024\n- Thủ tục sang tên nhanh chóng",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-nam-tu-liem-ha-noi/118464021.htm"
# }
# {
#   "name": "Hyundai Grand i10 2014 1.0 MT - 30000 km",
#   "year": "2014",
#   "price": "160.000.000 đ",
#   "description": "Cần bán Huyndai i10, 5 chỗ .Xe đi gia đình, sx 2014. Nhập khẩu Ấn Độ, dòng xe chạy mượt. Xe không trầy xướt, sạch sẽ. Giá bán cực tốt. Anh Chị cần che mưa che nắng cho con liên hệ. Có bớt ít mua nhanh. Giấy tờ Chính Chủ Giá Bán đến công chứng.",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-cam-le-da-nang/118385496.htm"
# }
# {
#   "name": "Mitsubishi Grandis 2006 Trắng, Siêu rộng, Siêu Bền",
#   "year": "2005",
#   "price": "190.000.000 đ",
#   "description": "Mitsubishi Grandis 2005 đăng ký lần đầu 2006. ( chiếc xe siêu lành, siêu bền ) 7 chỗ Siêu Rộng\nXe đăng Kiểm Phút Mốt,Xe tại Đà Nẵng \nXe Vừa Mua bảo hiểm, máy vẫn chạy êm ru, gầm bệ đã bảo dưỡng thay thế những thứ cần thiết .\n*Ghế đã thay toàn bộ Da màu đen. \n*Đã lên Màn androi và Camera hành Trình. \n*Điều hòa auto tự động lạnh sâu,( đã bảo dưỡng thêm gas+ dầu). Tất cả các hàng ghế đều có điều hòa nên mát rượi.\n em toàn chạy nhớt hãng, nước mát hãng, dầu trợ lái hãng, dầu hộp số hãng. \nXe em gốc màu Vàng cát, nay đổi sang màu trắng đổi trên cà vẹt lun rồi ạ. \nLẤY XE VỀ CHỈ VIỆC ĐỔ XĂNG VÀ CHẠY THÔI Ạ. \nChiếc xe cực chất \nGIÁ 190 , CHÍNH CHỦ SANG TÊN NHANH, XE TẠI ĐÀ NẴNG Ạ.",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-son-tra-da-nang/116998503.htm"
# }
# {
#   "name": "Kia Morning 2017 1.0 MT - 86000 km",
#   "year": "2017",
#   "price": "179.000.000 đ",
#   "description": "Bán Kia morning số sàn 2017:\nxe tư nhân ko kinh doanh dv còn cứng đẹp zin\nđi bền lành tiết kiệm xăng...\nGiá: 179 triệu\nxem tại Mỹ Đình, hn",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-nam-tu-liem-ha-noi/118457230.htm"
# }
# {
#   "name": "Kia CD5 2004 CD5 - 100000 km",
#   "year": "2004",
#   "price": "35.000.000 đ",
#   "description": "- Xe chạy cực kỳ tiết kiệm xăng, chỉ 5L/100km.\n- Xe cho anh em về xử đụng gia đình tâp lái .xe mới kiểm mới vè chỉ viêc đỗ xăng chạy  thôi ạ máy số bao êm thin thiết",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-thanh-pho-bien-hoa-dong-nai/117653798.htm"
# }
# {
#   "name": "Chevrolet Cruze 2010 LTZ 1.8 . AT số tự động .",
#   "year": "2010",
#   "price": "115.000.000 đ",
#   "description": "🚙 Chevrolet cruze sx2010.. ..số tự động..\n💰 Đưa em.. 115tr.. nhận xe về luôn..\n\n♻️ Xe máy số ngon - đồng sơn sạch đẹp - đã lên màng hình android - nội thất rin sạch sẽ - 4 vỏ dầy cui - bao ko đâm đụng hay ngập nước gi nghe ...\n\n👉 Góp thoải mái Ko cần thủ tục lu bu \n👉 Hổ trợ ace góp trực tiếp với em ko lo nợ xấu ..\n👉 Cho nợ trả chậm ko lấy lãi theo thoa thuận .\n\n🌎 Xem xe gân chân cầu cần thơ \"tx binh minh\"\n💰Giá bán 215tr ..\"báo ký rút hồ sơ xem xe thương lượng\"",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-thi-xa-binh-minh-vinh-long/118399174.htm#px=SR-stickyad-[PO-5][PL-top]"
# }
# {
#   "name": "THU - MUA GIÁ CAO TẤT CẢ CÁC DÒNG XE OTO",
#   "year": "2023",
#   "price": "50.000.000 đ",
#   "description": "Siêu thị Ô tô Hà Nội thu mua tất cả các dòng xe của các nhãn hiệu xe: Ford, Kia, Mazda, Mitsubishi, Honda, Mitsubishi, Honda, Hyundai, Toyota, Chevrolet, Nissan, Mecerder, BMW, AUDI...\nTầm giá từ 300 triệu trở lên.\n\nCam kết:\n👉 Giá nào cũng mua, giá thu cao nhất.\n 👉 Bảo mật thông tin khách hàng 100%.\n 👉 Thanh toán 100% trong ngày.\n 👉 Hoa hồng cao cho người giới thiệu.\n 👉 Xem xe tận nơi, thu xe 24/7.\n 👉 Hỗ trợ mọi thủ tục, giấy tờ công chứng sang tên.\nCả nhà có xe ới em nhé ạ 😘😘\n___________________________________________\n𝐒𝐢ê𝐮 𝐓𝐡ị Ô 𝐓ô 𝐇à 𝐍ộ𝐢 - Thương hiệu xe lướt số 1 Việt Nam.\n🏣 389 Quốc Lộ 13, Hiệp Bình Phước, Thủ Đức, Hồ Chí Minh.\nCode: #22915352_01",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-thanh-pho-thu-duc-tp-ho-chi-minh/117922237.htm#px=SR-stickyad-[PO-4][PL-top]"
# }
# {
#   "name": "Kia Morning 2015 - 100000 km",
#   "year": "2015",
#   "price": "180.000.000 đ",
#   "description": "Xe 5 chỗ, màu xám sang trọng.\n- Xe nhập khẩu nguyên chiếc từ Hàn Quốc.\n- Động cơ xăng 1.2L, tiết kiệm nhiên liệu.\n- Hộp số sàn, vận hành mượt mà.\n- Nội thất rộng rãi, tiện nghi\n- Xe đã qua sử dụng nhưng còn rất mới, chạy 100.000 km (không vặn đồng hồ)\n- Giá bán: 185 triệu. Thương Lượng \n- Liên hệ ngay để được tư vấn và xem xe\nLh: ***",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-tan-binh-tp-ho-chi-minh/118296361.htm"
# }
# {
#   "name": "Yaris nhà cần bán, Số tự động, xe rất đẹp",
#   "year": "2007",
#   "price": "199.000.000 đ",
#   "description": "Nhà cần bán, xe Toyota Yaris sx 2007 nhập Nhật Bản, thương hiệu số 1 về bền bỉ, lành, tiết kiệm xăng, xe số tự động, còn khá mới vì nhà em bảo dưỡng đầy đủ & cẩn thận.\nMàn Android, camera lùi, camera hành trình đủ hết, xe mới đăng kiểm, ai mua về sử dụng luôn ạ. Giá 199 triệu thôi, ai mua alo mình sớm, xem ở Hồ tùng mậu ạ.\n Em cảm ơn!!!",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-bac-tu-liem-ha-noi/117851776.htm"
# }
# {
#   "name": "Mitsubishi Jolie 2004 MPI Bánh Treo Xe Rin Đẹp",
#   "year": "2004",
#   "price": "95.000.000 đ",
#   "description": "Cần bán xe Jolie MPI bánh treo zin sản xuất cuối năm 2004 GĐ sử dụng rất kĩ xe còn zin nguyên bản từ trong ra ngoài. Khung sườn chắc chắn zin 100% không mục mọt không va chạm tai nạn bất kì chỗ nào,Nội thất ghế vải nỉ rin mới tinh sạch sẽ.Xe chạy rất đầm Máy nổ cực êm kim phun điện tử rất tiết kiệm xăng 8L/100km.Điều hòa trước sau 2 dàn lạnh buốt,gương kính chỉnh điện toàn bộ,nghe nhạc đầu DVD đọc thẻ USB+màn hình cảm ứng,Dàn vỏ mới thay lưu hành mới xét 1 năm...Nói chung xe còn chất lắm kiểu dáng lại đẹp 8 chỗ ngồi rộng rãi thỏa mái. A/C cần mua xin LH trực tiếp tôi,cảm ơn đã xem tin",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-huyen-xuan-loc-dong-nai/118461217.htm"
# }
# {
#   "name": "Bán Ford Focus 2009, MT, màu ghi vàng",
#   "year": "2009",
#   "price": "185.000.000 đ",
#   "description": "Tôi cần bán xe Ford Focus đăng ký 9/2009 (phiên bản ra mắt 8/2009) gia đình sử dung, máy êm, nồi đồng cối đá (xe quốc dân); xe không trầy xước, nứt vỡ, đảm bảo xe chưa tai nạn, không cấn đụng, không ngập nước. Xe đã lắp đồ chơi đầy đủ (Camera cạp lề, lùi, hành trình; Màn hình androi (vẫn còn đầu CD nguyên bản), loa bass, ghế da màu kem còn mới tinh (mới bọc được 6 tháng hết 10 triệu); nội thất sạch sẽ, thơm tho. Anh chị em ai có nhu cầu mua sử dụng liên hệ cho mình nhé. Tôi là Sỹ quan Quân đội, nên mua bán uy tín, ko lừa gạt ai. Thông tin chi tiết vui lòng liên hệ:\nNguyễn  Văn Đôn- SĐT: ***: - Địa chỉ: 40 Nguyễn Giản Thanh, Phường 15, Quận 10, Tp Hồ Chí Minh,",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-10-tp-ho-chi-minh/118456905.htm"
# }
# {
#   "name": "Mitsubitsi Jolie bánh treo màu bạc chính chủ",
#   "year": "2003",
#   "price": "86.000.000 đ",
#   "description": "Cần bán xe Jolie màu bạc bánh treo. Gia đình rất ít đi,nên còn rất mới khó tìm được chiếc thứ hai nay bán lại cho ai có nhu cầu. Đã lên dàn âm thanh pioner, loa súp cực hay màn hình Android wifi trên xe camera đầy đủ.2 bộ led gầm trắng rất sáng,ốp gỗ phủ gầm lót sàn,toàn xe nên chạy rất êm,tay lái cực nhẹ,4 vỏ mới dán phim cách nhiệt 3m máy lạnh cực lạnh. Đến xem xe trực tiếp và chạy thử sẽ rõ hơn. Tiền nào của đó thôi. Chính chủ:ủy quyền hoặc ký bán",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-go-vap-tp-ho-chi-minh/114970617.htm"
# }
# {
#   "name": "Chevrolet Spark 2010 LT 0.8 MT - 200000 km",
#   "year": "2010",
#   "price": "75.000.000 đ",
#   "description": "- Chevrolet Spark van 2010 Bạc\n- 2 chỗ\n- Máy móc êm, chạy bốc, tiết kiệm xăng\n- Xe đẹp, nội thất sạch sẽ, không mùi\n- Xe đã được kiểm định chất lượng\n- Liên hệ ngay để được tư vấn và xem xe!",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-thanh-pho-thu-duc-tp-ho-chi-minh/117442603.htm"
# }
# {
#   "name": "Toyota Vios_Xe gia đình_1 chủ_mới đăng kiểm",
#   "year": "2016",
#   "price": "199.000.000 đ",
#   "description": "Toyota Vios MT số sàn- không taxi không khoan đục xe gia đình. Bán đúng hôm nay cho ae nhanh gọn.\n- Xe mâm đúc - ghế da.. thắng đĩa\n- Kính gương chỉnh điện- 4 cửa kính điện\n- Xe đẹp, máy móc êm, chạy bốc, tiết kiệm xăng\n- Xe đã được kiểm tra kỹ lưỡng máy móc êm ngon.bao đi xa bao không đổ hơi không xôi nước.. máy lạnh mạnh.. âm thanh màn hình điện đóm đèn còi đầy đủ mọi chức năng..\n👉👉 xe chuẩn gia đình không taxi không khoan đục.. AE xem xe có khoan đục taxi gửi ae 10 triệu cafe... xe sản xất cuối 2014 đăng kí 2016 1 chủ đứng tên cavet đến nay\n👉👉Giá bán 199 bao công chứng qua tên\n📞 CALL trực tiếp không nhắn tin\n🏦số tài khoản : 888.888.888 ( ngân hàng OCB)",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-binh-tan-tp-ho-chi-minh/118091414.htm"
# }
# {
#   "name": "CẦN MUA XÁC Ô TÔ VÀ XE TẢI TAI NẠN GIÁ CAO",
#   "year": "2017",
#   "price": "120.000.000 đ",
#   "description": "Mình cần thu mua xác ô tô, xe tải, xe khách cũ, bị tai nạn, ngập nước, dính nợ xấu... Các dòng xe Isuzu, Huyndai, Toyota, Mazda, Hino,...\n📌 Dịch vụ đặc biệt:\n✅ Thu mua trên toàn quốc: HCM, Bình Dương, Đà Nẵng, Hà Nội,…\n✅ Giá thu mua cam kết giá tốt, cao hơn thị trường\n✅ Trực tiếp đến tận nơi để xem và báo giá cho khách hàng\n✅ Báo giá ngay khi khách hàng thông tin tình trạng xe\n✅ Nhân viên nhiệt tình, lịch sự\n✅ Không cần tốn nhiều thủ tục và giấy tờ\n✅ Thanh toán bằng tiền mặt một lần nhanh gọn cho khách hàng\n✅ Công ty tự vận chuyển xe, khách hàng không cần lo\n✅ Mua tận nơi 24/7 \nLIÊN HỆ ZALO MÌNH NGAY SĐT BÊN DƯỚI: \n\n#thumuaxe #xetainan #xengapnuoc #xecu #muaxe #cuongthumua #21033454_02",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-thanh-pho-thu-dau-mot-binh-duong/113671018.htm#px=SR-stickyad-[PO-5][PL-top]"
# }
# {
#   "name": "CHEVROLET SPARK 2016, SỐ SÀN MÁY XĂNG 1.0.",
#   "year": "2016",
#   "price": "150.000.000 đ",
#   "description": "Chevrolet Spark 2016, số sàn 4 máy 1.0, xe không lỗi, vừa sơn mới cả xe đẹp keng, gầm máy ngon.\nTham khảo chi tiết xe trên kênh youtube và Tik Tok Xe Cũ An Khang Thịnh.\nAnh chị thiện chí xem xe trực tiếp có bớt lộc.",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-tan-phu-tp-ho-chi-minh/117172010.htm"
# }
# {
#   "name": "Isuzu Trooper 2000  - 50000 km",
#   "year": "2000",
#   "price": "55.000.000 đ",
#   "description": "Isuzu trooper sản xuất năm 2000 nhập khẩu nhật bản nguyên chiếc.là xe 7 chỗ.là dòng doanh nhân.xe đẹp rộng như Ranrover.ngồi trong xe là cách biệt với thế giới bên ngoài.chống ồn cực chuẩn.đi lại cực an toàn.là phân khúc hạng sang cao cấp.là xe dành riêng cho chủ tich tổng tài. máy êm du.điều hoà lạnh buốt.lên xe phải mặc áo ấm không cảm lạnh.nguyên bản hết.sơn vỏ mỏng.gầm chắc như đinh.lốp zăng đúc theo xe.hai cầu đủ.cầu điện.phanh đĩa bốn bánh.gưing kính điện.gương gập điện.contron crui.xe bảo dưỡng thường xuyên.em cũng vừa bảo dưỡng để đi đăng kiểm.đăng kiểm mới.vỏ đẹp nguyên bản soi gương được.em cam kết xe ko đâm đụng ko va chạm.nếu sai biếu cả xe.xem xe tại bắc ninh.síp toàn quốc.giá",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-thanh-pho-bac-ninh-bac-ninh/118415906.htm"
# }
# {
#   "name": "Hyundai Grand i10 2014 1.0 MT - 125456 km",
#   "year": "2014",
#   "price": "175.000.000 đ",
#   "description": "- Hyundai Grand i10 2014  số sàn giá rẻ bản đủ xe cọp \n- Xe đẹp máy êm, chạy cực kỳ tiết kiệm xăng.\n- Xe đã được kiểm định chất lượng, đảm bảo không đâm đụng, ngập nước, thủy kích.\n- Xe được bảo hành 1 năm 100.000 km\nXem xe tại 364 nguyễn chi thanh",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-thanh-pho-buon-ma-thuot-dak-lak/118452374.htm"
# }
# {
#   "name": "Kia Morning 2008 EX 1.1 MT - 91000 km",
#   "year": "2008",
#   "price": "129.000.000 đ",
#   "description": "Morning 2008 số sàn \nChất xe zin đẹp \nTrang bị đầy đủ màn hình si nhan gương \nGiá hơn 100 tý xíu là có con xe chất lượng che nắng che mưa \nLh *** gặp Tú nhanh gọn lẹ",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-cai-rang-can-tho/118456801.htm"
# }
# {
#   "name": "Hyundai Getz 2009 1.4 AT nhập hàn quốc máy zin",
#   "year": "2009",
#   "price": "179.000.000 đ",
#   "description": "Huynh đai gezt đời 2009 số tự độmg \nXe nhập hàn quốc - máy 1.4 cực kỳ mạnh mẽ- đầm chắc!\nMáy số zin - keo chỉ zin- nội thất nguyên\nXe trang bj thêm nhều tiện ích \nXe mới đăng kiềm\nAc mua lh!",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-huyen-long-dien-ba-ria-vung-tau/118035302.htm"
# }
# {
#   "name": "Mazda 323 1995 1.6 MT - 210000 km",
#   "year": "1995",
#   "price": "17.500.000 đ",
#   "description": "Xe chạy bình thường chở đồ che nắng mưa ! Bán cho anh em nghiên cứu độ chế chạy chơi ! Máy móc nguyên zin\nNội thất cũ kỹ theo thời gian\nXe còn chạy được ngon lành \nEm bán giá phế liệu cho anh em \nXe hết hạn đăng kiểm đăng kiểm lại vẫn ok bán nhanh chốt nhanh cho gọn nhà!\nGiá thương lượng nhanh gọn \nCoi xe đổ xăng là chạy…\nEm hay bận nên vui lòng gọi ***",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-thanh-pho-da-lat-lam-dong/118403069.htm"
# }
# {
#   "name": "BÁN XE 7 CHỖ ĐỜI 2007 SSANGYONG HÀN QUỐC",
#   "year": "2007",
#   "price": "120.000.000 đ",
#   "description": "Cấn bán chiếc xe 7 chỗ đời 2007 hiệu ssangyong - Hàn Quốc, , xe đang hoạt động bình thường , máy móc nổ êm, mạnh, rộng rãi, thời gian xét xe 1 năm, bao xét xe. anh chị em nào cần mua xe giá rẻ bèo liên hệ thông tin trên.xe đang ở quận 12, Hồ Chí Minh",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-12-tp-ho-chi-minh/118117162.htm"
# }
# {
#   "name": "Chevrolet Spark 2016 - 87000 km",
#   "year": "2016",
#   "price": "159.000.000 đ",
#   "description": "Chevrolet spark 1.0 mt ls \n\n🌈 chuẩn xe gia đình 1 đời chủ mua mới chưa sang tên cho bất kì ai sổ sách thẻ hãng cỏn đủ .\n\n🌈 biển số 51 hồ chí minh không dính phạt nguội , rút gốc cộng thêm 2.5 củ . \n\n🌈⛄️ ngoại hình : Sơn đẹp ốc tán 7 màu gầm siêu đẹp . \n\n4 vỏ 70% . \n\nCam hành trình kết nối cam de . \n\nOdo 86000km đúng 1 chủ sử dụng máy rin rin rin rin rin .\n\nNội thất bọc da cực đẹp cabo chưa chạm cốp sau cửa 4 cánh chưa chạm . \n\n162.000.000 vnđ ( giá này giá bán ae thông cảm không thể bớt xe chuẩn gia đình ) . \n\n*** hoặc *** quí \n\nThị trấn thạnh mỹ đơn dương",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-thanh-pho-da-lat-lam-dong/118461038.htm"
# }
# {
#   "name": "Innova 2007 J lên full G e đứng tên chính chủ",
#   "year": "2007",
#   "price": "152.000.000 đ",
#   "description": "Innova 2007 J lên full G chuẩn nét chính chủ e đứng tên \nCông chứng uỷ quyền mua bán nhanh lẹ \nĐăng kiểm dài 2025 \nMáy móc chuẩn chỉ êm ru \nFull chức năng hoạt động bt \n2 dàn lạnh G \n4 mâm đúc G \n4 lốp còn 90% \nFull flim cách nhiệt cả xe \nMàn hình Android 9 inch \nCam lùi AHD \nCam hành trình \nĐồng sơn còn đẹp , nội thất sạch sẽ \nVừa bảo dưỡng toàn bộ còn bill 9 củ 5 về ae sẵn dùng ko cần làm gì thêm \n\nGiá e bán : 152 triệu\n\nXem xe Dĩ An Bình Dương \nSdt : *** ( zalo FB ) \n🚗CÓ GIAO XE TẬN NƠI CHO AE Ở XA",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-thanh-pho-di-an-binh-duong/118181769.htm"
# }
# {
#   "name": "Kia Morning 2011 SX 1.1 AT Sport - 90000 km",
#   "year": "2011",
#   "price": "192.000.000 đ",
#   "description": "Morning sport 2011 số tự động \nChất xe zin đẹp \nGiá 190tr \nBao kí rút hồ sơ\nLh ***",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-cai-rang-can-tho/118456545.htm"
# }
# {
#   "name": "Kia Morning 2017 Si 1.25 MT - 61000 km",
#   "year": "2017",
#   "price": "186.000.000 đ",
#   "description": "Đổi std cần bán morning 2017 số sàn, máy 1.25 \nxe đi được 60 ngàn km\nmáy nguyên zin chưa đụng chạm, không va chạm đâm đụng hay ngập nước \nbảo dưỡng hãng \nxe trang bị camera lùi, hành trình , đầu androi tích hợp \nchính chủ đứng tên giấy đăng ký \nai cần thì liên hệ em ạ",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-huyen-bau-bang-binh-duong/118444611.htm"
# }
# {
#   "name": "Toyota Zace 2005 GL - 113000 km",
#   "year": "2005",
#   "price": "160.000.000 đ",
#   "description": "Xe máy rin - số rin - gầm êm - 2 dàn lạnh - mâm lốp 70% - nội thất sạch sẽ - ko lỗi - lưu hành 5/ 2025 - camera đầy đủ - âm thanh nghe rất nét \n Xe chỉ bớt lộc \nXem xe thủ đức \nBao rút hồ sơ",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-thanh-pho-thu-duc-tp-ho-chi-minh/118452252.htm"
# }
# {
#   "name": "Ranger XLS 4X2AT khuyến mãi ưu đãi cho tháng 7",
#   "year": "2024",
#   "price": "138.000.000 đ",
#   "description": "Giá trên chỉ là giá niêm yết chưa bao gồm khuyến mãi\nĐANG CÓ XE RANGER XLS AT MÀU XANH GIAO TRONG NGÀY HỒ SƠ CẦM TAY GIÁ HOT NHẤT KHU VỰC MIỀN NAM, QUÀ TẶNG NGẬP TRÀN\nCAM KẾT GIÁ HOT NHẤT KHU VỰC MIỀN NAM, QUÀ TẶNG NGẬP TRÀN.\nSẼ ĐƯỢC ƯU TIÊN VỀ GIÁ KHI GỌI TRỰC TIẾP QUA HOTLINE, đặt lịch xem xe và lái thử tại nhà\n\nQuà Tặng - Theo chương trình bán hàng Ford Việt Nam\n✓ 2 năm bảo dưỡng miễn phí\n✓ Bảo hành mở rộng 2 năm.\n✓ Cứu hộ 3 năm miễn phí trên toàn quốc.\n✓ Dán thẻ VETC miễn phí\n\nKHÁCH HÀNG CÓ THỂ TRANG BỊ THÊM NHỮNG MÓN PHỤ KIỆN NHƯ SAU:\n+ Bảo hiểm thân vỏ\n+ Phim cách nhiệt 3M chính hãng bảo hành 10 năm\n+ Lót sàn 5D cao cấp\n+ Camera hành trình chính hãng\n+ Phủ gầm chống rỉ sét\n+ Phủ Ceramic bảo vệ sơn,\n+ Nắp thùng các loại như: cuộn điện, cuộn cơ, nắp thùng cao, nắp thung thấp 45 độ,...\n+ Lót Thùng sau\n+ Thanh thể thao\n+ Bọc trần,...\nHỗ trợ vay lên đến 70% - 95% giá trị xe, thời hạn từ 3 - 9 năm\nĐảm bảo lãi suất ưu đãi thị trường 5.8%/ năm, thủ tục nhanh gọn\nHỗ trợ khách hàng chứng minh thu nhập, cty mới thành lập, nợ chú ý, nợ xấu, cam kết hồ sơ vay bao đậu.\nĐăng ký xem xe & lái thử tại nhà\nHỗ trợ thủ tục đăng ký, đăng kiểm xe.",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-3-tp-ho-chi-minh/118002541.htm"
# }
# {
#   "name": "Mitsubishi Grandis 2005 2.4 AT - 160 km",
#   "year": "2005",
#   "price": "200.000.000 đ",
#   "description": "- Xe Mitsubishi Grandis 2005 2.4 AT.\n- Xe còn đẹp, máy êm, chạy bốc, tiết kiệm xăng.\n- Liên hệ để biết thêm thông tin chi tiết.",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-thi-xa-phu-my-ba-ria-vung-tau/118264759.htm"
# }
# {
#   "name": "Ford Fiesta 2011 - Xe đẹp, giá tốt",
#   "year": "2011",
#   "price": "196.000.000 đ",
#   "description": "Ford Fiesta 2011 - Xe đẹp, giá tốt\n\n- Xe đẹp, không đâm đụng, không ngập nước\n- Máy móc nguyên bản, chạy êm, tiết kiệm xăng\n- Nội thất sạch sẽ, thơm tho\n- Đã được bảo dưỡng Ford Fiesta 2012 chính nữ sử dụng\n- Số tự động\n- Máy xăng\n- Xe đẹp, chạy êm\n- Fiesta bản hatbach 2011 đẹp.xe được trang bị phanh abs.bóng khí.màn hình andoroi.cam hành trình.âm thanh như vũ trường.cam lùi cảm biến lùi.gương điện điều hoà hai chiều.tích hợp vô lăng.một dòng xe xuất Mỹ phom dáng đẹp rộng cao.cam kết xe nguyên bản của nhà sản xuất.k đâm va hay lỗi gì.xe tư nhân chính chủ.nên mua bán rất thuận tiện.\n\nGiá bán: 206 triệu\n\nLiên hệ ngay để được tư vấn và xem xe!",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-huyen-hoai-duc-ha-noi/118010006.htm"
# }
# {
#   "name": "Daewoo Matiz Super 0.8 AT 2009",
#   "year": "2009",
#   "price": "125.000.000 đ",
#   "description": "Mình bán Daewo Matiz Super 0.8 AT 2009 xe tên tư nhân chạy hơn 13v rất mới. Xe đã được ktra chất lượng , bác nào có nhu cầu mua đi lại loanh quanh xin liên hệ trực tiếp em để xem xe rồi chạy thử.",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-long-bien-ha-noi/118236161.htm"
# }
# {
#   "name": "Lecetti 2010 - Chính Chủ - màu Bạc đã qua sử dụng",
#   "year": "2010",
#   "price": "125.000.000 đ",
#   "description": "Mọi người ai thích thì liên hệ Em nhé! lacetti 2010. Em ở khu vực Cần Thơ (giá yêu thương, ngang tầm SH mode)\nZalo: ***",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-cai-rang-can-tho/118456498.htm"
# }
# {
#   "name": "Ford Everest 2005 máy dầu 2 cầu",
#   "year": "2005",
#   "price": "160.000.000 đ",
#   "description": "Cần bán xe Ford Everest  đời 2005  máy dầu 2 cầu 4 cái lốp mới tinh máy lạnh đầy đủ  xe này thì bao leo đèo dốc  máy móc không đổ hoi  xe chính chủ  xem xe ở TP HCM anh em xem xe là ưng ý liền miễn tiếp cò lái",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-huyen-binh-chanh-tp-ho-chi-minh/117871707.htm"
# }
# {
#   "name": "Hyundai Elantra 2008 1.6 MT - 11111 km",
#   "year": "2008",
#   "price": "140.000.000 đ",
#   "description": "- Hyundai Elantra 2008, màu bạc, 5 chỗ ngồi, số sàn.\n- Xe còn mới, máy móc nguyên bản, chạy êm, tiết kiệm xăng.\n- Xe đã được kiểm định chất lượng.\n- Thủ tục nhanh gọn,\n- Xe được trang bị camera lùi, camera hành trành, cảm biến lùi, màn hình androi 9 in, gương chỉnh điện, gương tự động gập lại khi block cửa, xin nhan tích hợp trên gương, tiết kiệm nhiên liệu 6l/100km, đăng kiểm đến tháng 7/2025, máy thì thầm, .\nGiá rẻ lắm rồi xin đừng trả giá",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-huyen-chau-thanh-ben-tre/118448156.htm"
# }
# {
#   "name": "Toyota Camry 2004 siêu cọp zin từng con ốc",
#   "year": "2004",
#   "price": "199.000.000 đ",
#   "description": "Toyota camry đời 2004, cam kết xe zin từng con ốc capo cửa cốp chưa đụng chạm, nguyên zin từ trước ra sau, sơn zin 7 80 %, máy số zin, xe của cán bộ chạy rất ít, mọi tính năng như ghế điện gập gương rèm che nắng 2 cửa gió điều hoà mọi thứ hoàn hảo, giàn gầm zin đẹp như mới, đăng kiểm mới 1 năm, Mua bán là phải công chứng luôn￼ Giá trên còn bớt lộc lá￼",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-12-tp-ho-chi-minh/118454635.htm"
# }
# {
#   "name": "Daewoo Lacetti Cdx 1/6 AT 1 chủ 30v full options",
#   "year": "2010",
#   "price": "175.000.000 đ",
#   "description": "Xe gia đình vừa mới đăng kiểm xong bán chiếc Daewoo Lacetti CDX bản cao cấp nhất 1.6 AT số tự động đề nổ Start/Stop cửa nóc nhập khẩu nguyên chiếc đky 2010 vẫn nguyên chính chủ gia đình sử dụng từ mới biển 30V-4 số biển Lộc Vĩnh Cửu Mãi Phát rất đẹp đi 8 vạn km zin.Bản cao cấp nhất cửa nóc đề nổ thông minh Start/Stop ko dùng chìa khoá.Tích hợp vô lăng,hệ thống âm thanh giải trí tiểu chuẩn 6 loa kết hợp với đầu đọc DVD màn Android mới nhất 06 đĩa,MP3 và Jack AUX/iPod camera cảm biến lùi.Hệ thống túi khí an toàn,sấy ghế lái phụ.Gương gập điện,kính điện.Hệ thống chống bó phanh ABS,EBD,cảm ứng tốc độ,cảnh báo cảm biến lùi.Điều hòa 2 chiều nóng lạnh tự động.Chính chủ gia đình sử dụng từ đầu nên ai mua mời ra văn phòng công chứng làm hợp đồng mua bán luôn cho yên tâm hoặc rút hồ sơ chuyển vùng sang tên đổi chủ thoải mái.Vừa mới đi đăng kiểm lại hôm nay xong vì ko dùng đến Tiền nào của ấy các bạn cứ đến xem gia đình tôi giữ gìn bảo quản xe như thế nào. Mua bán tại nhà riêng qua gặp gia đình thương lượng nói chuyện.Cảm ơn bạn đã xem tin đăng.",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-long-bien-ha-noi/103844244.htm"
# }
# {
#   "name": "🔱 MG HS 🔱 - new 100% - Chỉ 140tr là nhận xe",
#   "year": "2024",
#   "price": "140.000.000 đ",
#   "description": "🔥𝐌𝐆 𝐇𝐒  🚘Siêu phẩm comback với sự cải tiến về thiết kế mang đến một chiếc SUV hạng C với diện mạo hoàn toàn mới mạnh mẽ, cuốn hút cùng với nhiều nâng cấp giá trị. \n---Xe hiện tại đã có sẵn tại Showroom---\n🔥4 màu hot trend: Đ𝐞𝐧 𝐧𝐠𝐨̣𝐜 𝐭𝐫𝐚𝐢 - 𝐗𝐚́𝐦 𝐓𝐫𝐨- Đ𝐨̉ 𝐋𝐮̛̉𝐚- 𝐓𝐫𝐚̆́𝐧𝐠 𝐤𝐞𝐦 \n-----------------------------------------\n🚗SUV cỡ lớn - gầm cao - 5 chỗ \n⭐️ An toàn 5 sao tiêu chuẩn kép Châu Âu & ÚC\n✅Chiều dài cơ sở 2m7\n✅Động cơ 1.5  Turbo Tăng Áp\n✅Hộp số ly hợp kép 7 cấp \n✅Công Suất 160HP, 250Nm@1700-4400v\n✅Có 5 Chế độ lái : Eco-Normal-Sport-SuperSport-Custom\n✅Đèn nội thất sang xịn mịn \n✅ Bảo hành 5 năm\n-------------------------------------------------\n👉 Quà tặng phụ kiện chính hãng hấp dẫn.\n👉 Hỗ trợ vay 85% giá trị xe không cần chứng minh thu nhập.\n👉 Hỗ trợ lái thử tận nhà.\n👉 Xe nhìn quá nét, quá sang trọng, tinh tế. \n\n--------------***----------------\nMG VO VAN KIET\n>>>> 25 Võ Văn Kiệt, p16, q8, tpHCM",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-8-tp-ho-chi-minh/116253017.htm"
# }
# {
#   "name": "Toyota Innova 2007 G - 120000 km",
#   "year": "2007",
#   "price": "195.000.000 đ",
#   "description": "- Toyota Innova 2007 G\n- Màu vàng\n- Xe chạy 150000km\n- Xe đẹp, máy êm, nội thất sạch sẽ",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-binh-tan-tp-ho-chi-minh/118003385.htm"
# }
# {
#   "name": "BÁN Kia Morning 2012 SX 1.0 MT Sport - 80.000 km",
#   "year": "2012",
#   "price": "119.000.000 đ",
#   "description": "- Xe Kia Morning SX 1.0 MT Sport 2012, màu trắng, xe đẹp, máy móc nguyên bản, chạy êm, tiết kiệm xăng.\n- Xe trang bị đầy đủ tiện nghi: điều hòa, âm thanh, kính điện, gương điện, khóa điện, đầu CD, USB, Bluetooth, camera lùi,...\n- Xe đã được kiểm tra kỹ thuật toàn diện, đảm bảo chất lượng ***.",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-huyen-thang-binh-quang-nam/118456435.htm"
# }
# {
#   "name": "Daewoo Lacetti 2012 - 12345 km",
#   "year": "2012",
#   "price": "104.000.000 đ",
#   "description": "Cần bán lacciti 2011 đăng ký 2012 .. xe biển 47 chính chủ.. máy số gầm bệ cực chất.. mới bảo dưỡng hơn 10tr .. màn hình cam de đầy đủ.. k đâm đụng ngập nước.. k taxi dịch vụ.. giá 104tr xem xe tại bmt .. có nhận đổi xe khác bù trừ ạ...",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-thanh-pho-buon-ma-thuot-dak-lak/118321085.htm"
# }
# {
#   "name": "Hyundai Grand i10 nhập khẩu số tự động 2011",
#   "year": "2011",
#   "price": "185.000.000 đ",
#   "description": "Bán xe Hyundai i10 đời 2009, đăng ký 2011, số tự động AT\nXe Nhập khẩu nguyên chiếc 5 chỗ, gốc Cần Thơ\nXe thích hợp đi trong đô thị, nhỏ gọn, xoay xở tốt\nNước sơn nguyên bản zin theo xe, keo chỉ chuẩn nét\nĐộng cơ thì thầm: 1.1 siêu tiết kiệm nhiên liệu\nMáy móc êm ấm, khung gầm chắc chắn\nĐiều hòa mát sâu, đèn sương mù, hộp số nhẹ\nGương, kính chỉnh điện\nTrang bị Ghế da, phim cách nhiệt, xe được bảo dưỡng thường xuyên.\nKích thước: 3565 x 1595 x 1540\nXem xe tại Cần Thơ\nCảm ơn anh chị đã xem tin",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-cai-rang-can-tho/117233734.htm"
# }
# {
#   "name": "Suzuki 2016 - 91000 km",
#   "year": "2016",
#   "price": "149.000.000 đ",
#   "description": "E cần bán xe van Suzuki đời 2016. Vách ngăn. Máy lạnh mát rượi. \nBác nào mà mua xe cũ 5..6 năm chở lên thì trước sau cũng phải đại tu máy nhé. Xe e tất cả đều zin hết. Và mới đại tu máy hết 26tr. Bác nào mua thì yên tâm cứ thế mà chạy giống xe mới. Xe bán 149tr. Dc: cống hộp số 2. Đường thạnh Xuân 25. Quận 12. Ai mua gọi trực tiếp e nhé",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-12-tp-ho-chi-minh/118454365.htm"
# }
# {
#   "name": "CHEVROLET AVEO LT SỐ SÀN, KHÔNG LỖI.",
#   "year": "2016",
#   "price": "170.000.000 đ",
#   "description": "Chevrolet Aveo 2016, số sàn phun xăng 1.5, xe tươm tất sạch sẽ, đăng kiểm mới, còn ủy quyền được \nTham khảo chi tiết xe trên kênh youtube và Tik Tok Xe Cũ An Khang Thịnh.\nXe bán có cam kết và thương lượng bớt lộc khi xem xe trực tiếp.",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-tan-phu-tp-ho-chi-minh/116727232.htm"
# }
# {
#   "name": "Toyota Camry 1989 xe đep mâm đuc vo moi đk mới",
#   "year": "1989",
#   "price": "40.000.000 đ",
#   "description": "- Xe đẹp, máy êm, chạy ổn định\n- Giá: 42 triệu \n- Số chỗ ngồi:5c so sàn\n- Sedan\n- Trắng\n- 285000 km",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-12-tp-ho-chi-minh/116200081.htm"
# }
# {
#   "name": "Chevrolet Spark 2017 1.2 LT - 140000 km",
#   "year": "2017",
#   "price": "167.000.000 đ",
#   "description": "- Chevrolet Spark 2017 số sàn, giá tốt.\n- Xe màu trắng, nội thất đen, còn mới \n- Xe đã đi 140.000 km, bảo dưỡng định kỳ chính hãng \n- Xe không đâm đụng, không ngập nước, máy móc nguyên bản. \n- Xe được trang bị đầy đủ các tính năng: điều hòa, âm thanh, kính điện, khóa điện, mang hình Android ,cảm biến de\n- Xe phù hợp cho nhu cầu đi lại hàng ngày.và anh em chạy xe công nghệ",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-11-tp-ho-chi-minh/118456417.htm"
# }
# {
#   "name": "Chevrolet Spark 2013 Số tự động , 1 chủ từ đầu",
#   "year": "2013",
#   "price": "150.000.000 đ",
# ...
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-huyen-tran-de-soc-trang/117116805.htm"
# }
# {
#   "name": "Suzuki Ertiga Hybrid - 185 triệu nhận xe mới 100%",
#   "year": "2023",
#   "price": "185.000.000 đ",
#   "description": "Suzuki Ertiga Hybrid 2023 7 chỗ, tiết kiệm nhiên liệu bậc  phân khúc chỉ 5-6 lít / 100km\n- Xe mới 100%, nhập khẩu nguyên chiếc từ nước ngoài\n\n- Giá niêm yết: \nSố tự động AT: 608.000.000 đ\n🔥GIÁ ƯU ĐÃI TRONG THÁNG NÀY: \n519.000.000 đ + QUÀ TẶNG HẤP DẪN 🎁\n\nSố sàn MT: 538.000.000 đ\n🔥GIÁ ƯU ĐÃI TRONG THÁNG NÀY: \n449.000.000 đ + QUÀ TẶNG HẤP DẪN 🎁\n\nĐưa trước 170 - 189 triệu nhận xe\nTRẢ GÓP LÃI SUẤT 3.99% - 7.99% / NĂM\n\n- Hỗ trợ trả góp 80% giá trị xe, lãi suất ưu đãi\n- Hỗ trợ thủ tục đăng ký, đăng kiểm\n\n- Bảo hành 3 năm hoặc 100.000km\n- Xe có sẵn tại đại lý, vui lòng liên hệ để được tư vấn và xem xe.",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-binh-tan-tp-ho-chi-minh/117106886.htm"
# }
# {
#   "name": "BMW 3 Series 2004",
#   "year": "2004",
#   "price": "125.000.000 đ",
#   "description": "- BMW 3 Series 2004, màu vàng, nội thất da đen, xe nhập khẩu nguyên chiếc, biển số 5 số, xe đẹp, máy êm, chạy êm, xe còn rất mới, xe chạy rất tiết kiệm xăng, xe không đâm đụng, không ngập nước, không phạt nguội, xe chính chủ, giấy tờ đầy đủ, sang tên nhanh chóng. ĐIỆN THOẠI :***",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-hai-ba-trung-ha-noi/116961057.htm"
# }
# {
#   "name": "Thanh lý xác xe",
#   "year": "trước năm 1980",
#   "price": "12.000.000 đ",
#   "description": "thanh lý xác xe , máy móc hoạt động bình thường , xem xe ở An Phú , Bình Dương \n***",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-thanh-pho-thuan-an-binh-duong/117007515.htm"
# }
# {
#   "name": "BMW 3 Series 2002 Đẹp Giá Rẻ",
#   "year": "2002",
#   "price": "125.000.000 đ",
#   "description": "BMW 3 Series 2002 Đẹp Giá Rẻ\n\n➖ Xe đẹp, máy êm, nội thất sạch sẽ\n➖ Đăng ký 2002, xe chạy 100.000km\n➖ Xe trang bị đầy đủ các chức năng: điều hòa, âm thanh, kính điện, gương điện, ABS, túi khí,...\n➖ Xe còn rất mới, không đâm đụng, ngập nước, không lỗi lầm\n- Xem xe tại nhà ở Chung cư Andland Complex, Tố Hữu, Dương Nội, Hà Đông\n➖ Giá bán: 125 triệu",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-ha-dong-ha-noi/116951415.htm"
# }
# {
#   "name": "Toyota Liteace 1985",
#   "year": "1985",
#   "price": "95.000.000 đ",
#   "description": "Toyota Liteace máy cơ 1.5 nổ êm và tiết kiệm, điều hoà 2 giàn lạnh, đăng kiểm tháng 10/2024, sang tên được. Xe ở Sóc Sơn, Hà Nội",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-huyen-soc-son-ha-noi/117064564.htm"
# }
# {
#   "name": "Toyota Corolla 2001 số sàn",
#   "year": "2001",
#   "price": "122.000.000 đ",
#   "description": "- 🚗 Toyota Corolla 2001 số sàn.\n- ⚙️ Odo 100km.\n- ⛽️ Sử dụng nhiên liệu Xăng.\n- 💺 Số chỗ ngồi: 5.\n- ⚙️ Hộp số số sàn.\n- 💸 Giá bán: 122 triệu (thương lượng cho khách thiện chí).",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-huyen-hoa-thanh-tay-ninh/117116472.htm"
# }
# {
#   "name": "i10 2015 siêu đẹp",
#   "year": "2015",
#   "price": "158.000.000 đ",
#   "description": "I10 2015 không lỗi\nKeo chỉ còn nguyên , tôn mỏng tanh , máy gầm cực êm , nội thất sạch sẻ lên nhìu đồ chơi , đăng kiểm đến tháng 4/2025 \nGiá 1xx triệu \nXem xe tại phước An ***",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-huyen-krong-pac-dak-lak/117106230.htm"
# }
# {
#   "name": "Corolla nhập khẩu số tự động",
#   "year": "2006",
#   "price": "195.000.000 đ",
#   "description": "Toyota Corolla  1.8  nhập khẩu số tự động\nmáy móc zin Gầm bệ chắc,xe gia đình đi cực ít mới 9 vạn cam kết chuẩn số km ko tua\nnội ngoại thất bọc da còn đẹp như mới\nxem xe tại BẮC NINH chính chủ\nliên hệ qua zalo theo sdt trên nhe",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-huyen-tien-du-bac-ninh/116960980.htm"
# }
# {
#   "name": "Ford Laser 2002",
#   "year": "2002",
#   "price": "105.000.000 đ",
#   "description": "Ford Laser 2002 \nXe đẹp , máy êm , nội thất đẹp , xe chạy 48000 km xe không lỗi gầm bệ chắc chắn .xem xe trực tiếp sẽ biết ngay .xe bao giấy tơd hợp lệ \nGiá 105tr \nLiên hệ :***",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-thi-xa-ben-cat-binh-duong/116948743.htm"
# }
# {
#   "name": "Mercedes Benz GLK 250 2.0 2013",
#   "year": "2010",
#   "price": "56.500.000 đ",
#   "description": "Xe đời 2013 Fom mới.. hộp số 7 cấp mượt mà.. cần số điện\nMáy 2.0 cực tiết kiệm Eco .. xe vừa bảo dưỡng hãng hơn 100tr .. nội thất zin nhứ mới .. máy số zin 100%\nXem xe tại tp hải dương",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-long-bien-ha-noi/117007075.htm"
# }
# {
#   "name": "Jolie 2001 rẻ hơn xe máy vừa đăng kiểm xong",
#   "year": "2001",
#   "price": "50.000.000 đ",
#   "description": "Xe đang sử dụng tốt ko lỗi lầm\nMáy móc ngon bao đi xa ko hư vặt ko sôi nước\nĐiều hoà 2 chiều nóng lạnh.màn android.cam lùi\nVừa đăng kiểm xong\nLên đời nên bán lại",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-huyen-di-linh-lam-dong/117116403.htm"
# }
# {
#   "name": "Xe carnival 2006 đẹp",
#   "year": "2006",
#   "price": "140.000.000 đ",
#   "description": "Xe Carrnival 2006, Số sàn như hình, có màn hình endroi và camara 360 độ, máy còn ngon, nội thất còn mới",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-go-vap-tp-ho-chi-minh/116960594.htm"
# }
# {
#   "name": "Xe Motor Honda CB250 Nighthawk máy êm",
#   "year": "2018",
#   "price": "75.000.000 đ",
#   "description": "Xe ba mình đi dư dùng, máy êm ru\n- Honda NightHawk máy LA\n- Xe ba mình chạy kiểng , hầu như trùm mền ít đi\n- xem xe ở quận tân phú",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-tan-phu-tp-ho-chi-minh/115456392.htm"
# }
# {
#   "name": "lên đời cần bán",
#   "year": "2009",
#   "price": "165.000.000 đ",
#   "description": "xe máy móc êm ru keo chỉ còn . mới bão dưỡng máy còn bill",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-ngu-hanh-son-da-nang/117116113.htm"
# }
# {
#   "name": "Bán tai Jac 2019",
#   "year": "2019",
#   "price": "17.500.000 đ",
#   "description": "- Xe nhập khẩu nguyên chiếc từ Mỹ\n- Động cơ Hybrid tiết kiệm nhiên liệu\n- Xe còn mới 99%\n- Giá bán: 17,500,000\nXe chạy dc 4v. Mới dk. Mới bảo dưỡng. \nAi có nhu cầu liên hệ.",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-huyen-minh-hoa-quang-binh/116960496.htm"
# }
# {
#   "name": "Daewoo Gentra 2011",
#   "year": "2011",
#   "price": "95.000.000 đ",
#   "description": "Daewoo Gentra 2011 \n\n- Đăng ký 2011 \n\n- Xe đẹp \n\n- Máy móc êm \n\n- Xe chạy rất ổn định \n\n- Giá 115",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-cai-rang-can-tho/116948730.htm"
# }
# {
#   "name": "Daewoo Lanos 2001 Số Sàn Bạc",
#   "year": "2001",
#   "price": "32.000.000 đ",
#   "description": "- Daewoo Lanos 2001 số sàn, màu bạc, nhập khẩu nguyên chiếc.\n- Xe trang bị động cơ xăng 1.5L, hộp số sàn 5 cấp, dẫn động cầu trước.\n- Lăn bánh 210.000km.\n- Xe trang bị đầy đủ tiện nghi: điều hòa, radio,  kính chỉnh điện, \n- Cam kết chất lượng xe.\n-",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-huyen-dan-phuong-ha-noi/117064194.htm"
# }
# {
#   "name": "Kia Carnival 2.2D sinature 2022 full dầu 1 chủ",
#   "year": "2022",
#   "price": "127.900.000 đ",
#   "description": "👉 KIA Carnival Dầu 2.2D . Signature Cao cấp nhất 7 chỗ. Dkld 2022- 1 chủ sd .rất mới \nXe đi được 50 ngàn Km Zin . Full lịch sử bảo dưỡng tại hãng không thiếu ngày nào. \nCheck ték thỏa mãi bất kỳ đâu. \nSơn Zin gần cả xe. Nội thất Mới nguyên. Lốp theo xe cả dàn còn mới nguyên.  \nGiá e bán bao rut hs - sang tên toàn quốc :\n1tỷ279tr còn thương lương…\n\n🚖 Xem xe alo e Bình.",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-huyen-hoc-mon-tp-ho-chi-minh/117004485.htm"
# }
# {
#   "name": "Ford Focus std - bản đủ 2005  - 58000 km",
#   "year": "2005",
#   "price": "175.000.000 đ",
#   "description": "ford focus số tự động bản đủ 2005! full lich sử hãng, gần 20 năm mới đi hơn 5 vạn, hàng sưu tầm, máy móc, nội thất zin nguyên bản! trước mua 120 cây vàng, nay bán rẻ như cho hơn 2 cây vàng (175tr)! quá hợp lý cho một con xe độc nhất vô nhị!",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-huyen-thong-nhat-dong-nai/117115861.htm"
# }
# {
#   "name": "Suzuki 2006",
#   "year": "2006",
#   "price": "55.000.000 đ",
#   "description": "LÊN XE LỚN CẦN BÁN E SUZUKI 500K ĐỜI 205.XE MỚI ĐĂNG KIỂM XONG\n55T. XEM.XEM XE TẠI BÌNH DƯƠNG\nXE MÁY NỔ ÊM NHƯ XE DU LỊCH\nACE Ai HỢP THÌ LH : ***",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-thanh-pho-thuan-an-binh-duong/116959948.htm"
# }
# {
#   "name": "Hyundai Grand i10 2016",
#   "year": "2016",
#   "price": "185.000.000 đ",
#   "description": "- Xe mới 100%, biển số đẹp 5 số.\n- Xe trang bị động cơ 1.2L, hộp số tự động 4 cấp.\n- Nội thất bọc da cao cấp, ghế lái chỉnh điện, màn hình giải trí trung tâm, hệ thống âm thanh 6 loa.\n- Xe đã được kiểm tra và bảo dưỡng định kỳ tại hãng, cam kết không đâm đụng, không ngập nước.\n- Hỗ trợ trả góp lên đến 70% giá trị xe, thủ tục nhanh chóng, lãi suất ưu đãi.\n- Liên hệ ngay để biết thêm thông tin chi tiết và đặt lịch lái thử.",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-tay-ho-ha-noi/117063622.htm"
# }
# {
#   "name": "Xe tải Daihatsu Hijet 2000",
#   "year": "2004",
#   "price": "12.000.000 đ",
#   "description": "Bán xe daihatsu 7 chỗ không niên hạn,máy vẩn nổ côn số nhẹ nhàng .giấy tờ đây đầy đủ bỏ khám 2 năm  rồi.nay muốn bán.xem xe tại quảng xương Thanh Hóa",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-huyen-quang-xuong-thanh-hoa/117003388.htm"
# }
# {
#   "name": "Cần bán xe MB100,2003,9 chỗ ko niên hạn hạn",
#   "year": "2003",
#   "price": "110.000.000 đ",
#   "description": "Xe hoạt động bình thường,máy lạnh đầy đủ, xe đang chạy chở học sinh, cần lên đời,ai cần lh",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-thanh-pho-vung-tau-ba-ria-vung-tau/116947537.htm"
# }
# {
#   "name": "đổi xe khác nên bán em kia spetra 2005",
#   "year": "2005",
#   "price": "60.000.000 đ",
#   "description": "mua xe tập lái dc 1 năm xe em đã thay lốp mới, làm lại máy bốc, thay ghế da bọc trần chống nóng, loanh quanh mất cả hơn 30 rồi, giờ em muốn đổi xe nên bán lại, đảm bảo xem là ưng, em ở kim bảng hà nam",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-huyen-kim-bang-ha-nam/117115670.htm"
# }
# {
#   "name": "Gả em xe nhà rất ít đi. Nước sơn cực mới",
#   "year": "2005",
#   "price": "180.000.000 đ",
#   "description": "Nhà em có 2 xe 4 và 7 chỗ nhưng hầu như chỉ đi 7 chỗ để chở con cái nên con xe Lancer Galla 2.0 này hầu như toàn đắp chăn nằm yên trong bãi  mái che quanh nâm. Em đẹp, duyên dáng và được nhà em chăm chút, yêu thương suốt những năm qua. \nGiờ em đổi chỗ làm gần nhà nên đành chia tay em nó. Mong được chủ mới san sẻ tình yêu thương. Giá 180 triệu quá đẹp cho 1 em sedan 2.0 mà nước sơn gần như mới bóng. Nội thất đầy đủ, điều hòa mát lạnh, máy xe gin không hề tháo dỡ. \nCác cụ các mợ vui lòng ib em *** để em gửi thêm hình ảnh và thông tin. \nCác bác thợ vui lòng không bóc giá quá tay ak. Xe em cực mới vì có chỗ để cực xịn suốt những năm qua. Hơn chục năm sở hữu rồi. Nhiều tình cảm lắm ak.",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-dong-da-ha-noi/116959859.htm"
# }
# {
#   "name": "Mercedes Benz 1982 5 chỗ số sàn",
#   "year": "1982",
#   "price": "120.000.000 đ",
#   "description": "Mercedes Benz 1982 5 chỗ số sàn, xe đẹp.\n\n- Xe nhập khẩu nguyên chiếc từ Đức.\n- Xe còn rất mới, nội thất đẹp, ngoại thất đẹp.\n- Xe chạy rất êm.\n- Xe đã được kiểm tra kỹ thuật toàn diện, đảm bảo chất lượng ***.",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-thanh-pho-tan-an-long-an/117063197.htm"
# }
# {
#   "name": "Hyundai Grand i10 2019",
#   "year": "2019",
#   "price": "32.500.000 đ",
#   "description": "- Hyundai Grand i10 2019, màu đỏ, nội thất đẹp, sang trọng, trang bị đầy đủ tiện nghi.\n- Xe đã qua sử dụng, còn mới, chất lượng tốt.\n- Liên hệ để biết thêm thông tin.",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-thanh-pho-thanh-hoa-thanh-hoa/117002905.htm"
# }
# {
#   "name": "Spark 2009, màu trắng",
#   "year": "2009",
#   "price": "65.000.000 đ",
#   "description": "Spark 2009 mới đại tu khung gầm, máy móc. 20tr\nĐầy đủ đồ chơi.",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-ngu-hanh-son-da-nang/116947334.htm"
# }
# {
#   "name": "BMW M4 2020 body kit Ranjin - Giá thương lượng",
#   "year": "2020",
#   "price": "10.000.000 đ",
#   "description": "Mùa Euro đã đến, tiện nên mình cho đi 1 con M4 2020 đã được độ sẵn gói độ Raijin màu xám như ảnh. Giao dịch trực tiếp tại Los Santos. Xe 1 đời chủ cam kết chưa đâm đụng ngập nước",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-ba-dinh-ha-noi/117061430.htm"
# }
# {
#   "name": "Đời 2001 không hết niên hạn.",
#   "year": "2001",
#   "price": "45.000.000 đ",
#   "description": "Xe chính chủ một đời. Cần bán mua xe mới.",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-cam-le-da-nang/117001592.htm"
# }
# {
#   "name": "Honda 2011",
#   "year": "2011",
#   "price": "15.000.000 đ",
#   "description": "Xe của hãng honda, vẫn đang dùng bình thường, màu đen",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-lien-chieu-da-nang/116946785.htm"
# }
# {
#   "name": "Hyundai Getz 2009 1.1 MT - xe nhập khẩu",
#   "year": "2009",
#   "price": "82.000.000 đ",
#   "description": "Xe chính chủ, vừa đi đăng kiểm về, hạn tới 2025, giá mấy chục triệu cho bác nào về thay xe máy tránh mưa tránh nắng.",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-thanh-pho-vinh-nghe-an/117061132.htm"
# }
# {
#   "name": "Toyota Zace 2005, xe đep lam, giá 185 triệu",
#   "year": "2004",
#   "price": "185.000.000 đ",
#   "description": "- Xe Toyota Zace 2005; xe dep lam…giá 185 triệu.\nSon zin con nhiều; máy zin; so zin chưa mở; nội thất ghế ni zin… không tiếp cò lái.. bán người dùng… xem xe khu hành chính di linh.",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-huyen-di-linh-lam-dong/117001473.htm"
# }
# {
#   "name": "SH mode màu đỏ mận",
#   "year": "2018",
#   "price": "38.000.000 đ",
#   "description": "Xe đi ít còn rất mới . Giá cả hợp lý",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-hai-ba-trung-ha-noi/117059341.htm"
# }
# {
#   "name": "Xe 7 chỗ giá rẻ hơn xe máy cho ae  tập lay",
#   "year": "2007",
#   "price": "30.000.000 đ",
#   "description": "Xe chạy ok giá rẻ cho anh em tập lay lh ***",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-huyen-cau-ke-tra-vinh/116944508.htm"
# }
# {
#   "name": "Bán xe gia đình sử dụng",
#   "year": "2004",
#   "price": "55.000.000 đ",
#   "description": "Bán cd5 đời 2004, gia đình đang sử dụng, xem xe tp mới BD",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-thi-xa-ben-cat-binh-duong/116943678.htm"
# }
# {
#   "name": "Mitsubishi Lancer Gala 1.6 MT 2005 xanh lá",
#   "year": "2005",
#   "price": "110.000.000 đ",
#   "description": "- 🚗 Mitsubishi Lancer Gala 1.6 MT 2005 xanh lá.\n- 💺 Số chỗ ngồi: 5\n- ⚙️ Hộp số sàn.\n- 💰 Giá bán: 120 triệu (thương lượng cho khách thiện chí).\nLiên hệ sdt ***\nHoặc zalo ***",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-huyen-dai-loc-quang-nam/117059249.htm"
# }
# {
#   "name": "Mazda BT 50 2011 5 chỗ,nhập thai,máy dầu chính chủ",
#   "year": "2011",
#   "price": "198.000.000 đ",
#   "description": "- Xe Mazda BT 50 2011 xe nhập thái\n- Xe số sàn\n- Xe màu trắng\n- Xe chạy 17 vạn\n- máy êm,  vẫn đi lại ok\n- Giá bán: 198tr\n-  5 chỗ ngồi\n- máy dầu 2 cầu\n- điều hoà mát rét hơn tủ lạnh\n- đăng kiểm mới, chính chủ, thay dầu bảo dưỡng định kỳ\nmàn hình andoy cam lùi đầy đủ, xe này đi phượt thì hết ý",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-huyen-dong-anh-ha-noi/116940961.htm"
# }
# {
#   "name": "Kia Morning 2015 Số Sàn tại Quảng Nam",
#   "year": "2015",
#   "price": "155.000.000 đ",
#   "description": "🚘 Hơn 100 triệu tội gì mua xe máy làm gì\n_ Em bán Kia Morning 2015 số sàn\n_ Máy móc rất êm. Chạy cực kỳ đằm chắc\n_ Đồ chơi màng hình camera trước sau ko thiếu thứ gì\n_ Tuyệt đối ko tai nạn, ko ngập nước\n_ Giá hợp lý : 155tr\nMọi người cần xe che nắng che mưa thay thế xe máy gọi e\n☎️ \nCoi xe Thăng Bình, Quảng Nam",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-quan-lien-chieu-da-nang/117057166.htm"
# }
# {
#   "name": "Kia 2011 bán 135tr",
#   "year": "2011",
#   "price": "135.000.000 đ",
#   "description": "- Xe chạy tốt, máy móc nguyên bản.\n- Xe gia đình sử dụng, nội thất sạch sẽ.",
#   "urlcar": "https://xe.chotot.com/mua-ban-oto-thanh-pho-viet-tri-phu-tho/117056724.htm"
# }
